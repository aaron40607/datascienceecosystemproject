# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In This Notebook Data Science tools and Ecosysem are summarized

# %% [markdown]
# # Some of the popular laanguages data scientists use are ;
#
# 1. Python
# 2. R
# 3. Sql

# %% [markdown]
# # Some of the commonly used libraries used by the Data Scientists are;
#
# 1. Pandas
# 2. Numpy
# 3. Matplotlib

# %% [markdown]
# | Data Science tools |
# |--------------------|
# |  Jupyter notebook  |
# |     Rstudio        |
# |       VS           |

# %% [markdown]
# ### Below are the following example of evaluating arithmetic experssion in python

# %%
(3 * 4)+5
# Out:
# 17

# %%
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# **Objectives:**
#
# - List popular languages for Data Science
# - List commonly used libraries in Data Science
# - Create tables using markdown
# - Perform arithmetic expressions in Python
# - Share notebook using GitHub

# %% [markdown]
# ## Author
#
# Aaron T Pappachan
